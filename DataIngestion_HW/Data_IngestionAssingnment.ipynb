# %%
# %%capture
# !pip install dlt[duckdb] # Install dlt with all the necessary DuckDB dependencies

# %%
import dlt

# %% [markdown]
# Question 1 - What is the sum of the outputs of the generator for limit = 5?

# %%
def square_root_generator(limit):
    n = 1
    while n <= limit:
        yield n ** 0.5
        n += 1

# Example usage:
limit = 5
generator = square_root_generator(limit)
sum  = 0

for sqrt_value in generator:
    print(sqrt_value)
    sum = sum + sqrt_value
print("sum of outputs for the generator of limit 5:", sum)
# Out:
# 1.0
# 1.4142135623730951
# 1.7320508075688772
# 2.0
# 2.23606797749979
# sum of outputs for the generator of limit 5: 8.382332347441762

# %% [markdown]
# Question 2: What is the 13th number yielded

# %%
def square_root_generator(limit):
    n = 1
    while n <= limit:
        yield n ** 0.5
        n += 1

# Example usage:
limit = 13
generator = square_root_generator(limit)
sum  = 0
c = 1
for sqrt_value in generator:
    print("Line Number :", c,"-", sqrt_value)
    c = c + 1
# Out:
# Line Number : 1 - 1.0
# Line Number : 2 - 1.4142135623730951
# Line Number : 3 - 1.7320508075688772
# Line Number : 4 - 2.0
# Line Number : 5 - 2.23606797749979
# Line Number : 6 - 2.449489742783178
# Line Number : 7 - 2.6457513110645907
# Line Number : 8 - 2.8284271247461903
# Line Number : 9 - 3.0
# Line Number : 10 - 3.1622776601683795
# Line Number : 11 - 3.3166247903554
# Line Number : 12 - 3.4641016151377544
# Line Number : 13 - 3.605551275463989

# %%
def people_1():
    for i in range(1, 6):
        yield {"ID": i, "Name": f"Person_{i}", "Age": 25 + i, "City": "City_A"}
data = []
for person in people_1():
    print(person)
    data.append(person)
# Out:
# {'ID': 1, 'Name': 'Person_1', 'Age': 26, 'City': 'City_A'}
# {'ID': 2, 'Name': 'Person_2', 'Age': 27, 'City': 'City_A'}
# {'ID': 3, 'Name': 'Person_3', 'Age': 28, 'City': 'City_A'}
# {'ID': 4, 'Name': 'Person_4', 'Age': 29, 'City': 'City_A'}
# {'ID': 5, 'Name': 'Person_5', 'Age': 30, 'City': 'City_A'}

# %%
pipeline = dlt.pipeline(pipeline_name="user_datapipeline",
						destination='duckdb',
						dataset_name='user_data')

# run the pipeline with default settings, and capture the outcome
info = pipeline.run(data,
                    table_name="users",
                    write_disposition="replace")

# show the outcome
print(info)
# Out:
# Pipeline user_datapipeline load step completed in 0.43 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset user_data
# The duckdb destination used duckdb:////content/user_datapipeline.duckdb location to store data
# Load package 1708197399.4377146 is LOADED and contains no failed jobs

# %%
# show outcome

import duckdb

conn = duckdb.connect(f"{pipeline.pipeline_name}.duckdb")

# let's see the tables
conn.sql(f"SET search_path = '{pipeline.dataset_name}'")
print('Loaded tables: ')
display(conn.sql("show tables"))
# Out:
# Loaded tables:
# ┌─────────────────────┐
# │        name         │
# │       varchar       │
# ├─────────────────────┤
# │ _dlt_loads          │
# │ _dlt_pipeline_state │
# │ _dlt_version        │
# │ users               │
# └─────────────────────┘

# %%
print("\n\n\n http_download table below:")

rides = conn.sql("SELECT * FROM users").df()
display(rides)
# Out:
#  http_download table below:
#    id      name  age    city        _dlt_load_id         _dlt_id
# 0   1  Person_1   26  City_A  1708197399.4377146  X3EYVoTjPAq4Vw
# 1   2  Person_2   27  City_A  1708197399.4377146  4py1yi2dvEqZ3Q
# 2   3  Person_3   28  City_A  1708197399.4377146  WGy4+GTwsWoFkQ
# 3   4  Person_4   29  City_A  1708197399.4377146  /udSrZwDny9l5Q
# 4   5  Person_5   30  City_A  1708197399.4377146  o4SOBwjr0p4Bwg

# %%
print("Total age of the people for first generator :", rides['age'].sum())
# Out:
# Total age of the people for first generator : 140

# %%
def people_2():
    for i in range(3, 9):
        yield {"ID": i, "Name": f"Person_{i}", "Age": 30 + i, "City": "City_B", "Occupation": f"Job_{i}"}

data1 = []
for person in people_2():
    print(person)
    data1.append(person)

info = pipeline.run(data1,
                    table_name="users",
                    write_disposition="append")
# Out:
# {'ID': 3, 'Name': 'Person_3', 'Age': 33, 'City': 'City_B', 'Occupation': 'Job_3'}
# {'ID': 4, 'Name': 'Person_4', 'Age': 34, 'City': 'City_B', 'Occupation': 'Job_4'}
# {'ID': 5, 'Name': 'Person_5', 'Age': 35, 'City': 'City_B', 'Occupation': 'Job_5'}
# {'ID': 6, 'Name': 'Person_6', 'Age': 36, 'City': 'City_B', 'Occupation': 'Job_6'}
# {'ID': 7, 'Name': 'Person_7', 'Age': 37, 'City': 'City_B', 'Occupation': 'Job_7'}
# {'ID': 8, 'Name': 'Person_8', 'Age': 38, 'City': 'City_B', 'Occupation': 'Job_8'}

# %%
import duckdb

conn = duckdb.connect(f"{pipeline.pipeline_name}.duckdb")

# let's see the tables
conn.sql(f"SET search_path = '{pipeline.dataset_name}'")
print('Loaded tables: ')
display(conn.sql("show tables"))

print("\n\n\n http_download table below:")

rides1 = conn.sql("SELECT * FROM users").df()
display(rides1)
# Out:
# Loaded tables:
# ┌─────────────────────┐
# │        name         │
# │       varchar       │
# ├─────────────────────┤
# │ _dlt_loads          │
# │ _dlt_pipeline_state │
# │ _dlt_version        │
# │ users               │
# └─────────────────────┘
#  http_download table below:
#     id      name  age    city        _dlt_load_id         _dlt_id occupation
# 0    1  Person_1   26  City_A  1708197399.4377146  X3EYVoTjPAq4Vw       None
# 1    2  Person_2   27  City_A  1708197399.4377146  4py1yi2dvEqZ3Q       None
# 2    3  Person_3   28  City_A  1708197399.4377146  WGy4+GTwsWoFkQ       None
# 3    4  Person_4   29  City_A  1708197399.4377146  /udSrZwDny9l5Q       None
# 4    5  Person_5   30  City_A  1708197399.4377146  o4SOBwjr0p4Bwg       None
# 5    3  Person_3   33  City_B   1708197648.414521  N0sSqQuILqyN2A      Job_3
# 6    4  Person_4   34  City_B   1708197648.414521  s1CHR0lS/HoZyg      Job_4
# 7    5  Person_5   35  City_B   1708197648.414521  3C3IdNzIy2uz4w      Job_5
# ...

# %%
print("Total age of the people for both generator :", rides1['age'].sum())
# Out:
# Total age of the people for both generator : 353

# %% [markdown]
# 3. Merge a generator
# Re-use the generators from Exercise 2.
#
# A table's primary key needs to be created from the start, so load your data to a new table with primary key ID.
#
# Load your first generator first, and then load the second one with merge. Since they have overlapping IDs, some of the records from the first load should be replaced by the ones from the second load.
#
# After loading, you should have a total of 8 records, and ID 3 should have age 33.
#
# Question: Calculate the sum of ages of all the people loaded as described above.

# %%
pipeline = dlt.pipeline(pipeline_name="merge_datapipeline",
						destination='duckdb',
						dataset_name='merge_user_data')

# run the pipeline with default settings, and capture the outcome
info = pipeline.run(data,
                    table_name="merge_test",
                    write_disposition="replace")

# show the outcome
print(info)
# Out:
# Pipeline merge_datapipeline load step completed in 0.40 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset merge_user_data
# The duckdb destination used duckdb:////content/merge_datapipeline.duckdb location to store data
# Load package 1708199373.01165 is LOADED and contains no failed jobs

# %%
import duckdb

conn = duckdb.connect(f"{pipeline.pipeline_name}.duckdb")

# let's see the tables
conn.sql(f"SET search_path = '{pipeline.dataset_name}'")
print('Loaded tables: ')
display(conn.sql("show tables"))

print("\n\n\n http_download table below:")

rides1 = conn.sql("SELECT * FROM merge_test").df()
display(rides1)
# Out:
# Loaded tables:
# ┌─────────────────────┐
# │        name         │
# │       varchar       │
# ├─────────────────────┤
# │ _dlt_loads          │
# │ _dlt_pipeline_state │
# │ _dlt_version        │
# │ merge_test          │
# └─────────────────────┘
#  http_download table below:
#    id      name  age    city      _dlt_load_id         _dlt_id occupation
# 0   1  Person_1   26  City_A  1708199373.01165  /uGYxwjd4Se/DA       None
# 1   2  Person_2   27  City_A  1708199373.01165  fKec+ql1oUT+Uw       None
# 2   3  Person_3   28  City_A  1708199373.01165  OoLxmMLOnAZWDw       None
# 3   4  Person_4   29  City_A  1708199373.01165  HiV9V4SH63zQEg       None
# 4   5  Person_5   30  City_A  1708199373.01165  Ipw5bRZGBzZm9A       None

# %%
print(data1)
# Out:
# [{'ID': 3, 'Name': 'Person_3', 'Age': 33, 'City': 'City_B', 'Occupation': 'Job_3'}, {'ID': 4, 'Name': 'Person_4', 'Age': 34, 'City': 'City_B', 'Occupation': 'Job_4'}, {'ID': 5, 'Name': 'Person_5', 'Age': 35, 'City': 'City_B', 'Occupation': 'Job_5'}, {'ID': 6, 'Name': 'Person_6', 'Age': 36, 'City': 'City_B', 'Occupation': 'Job_6'}, {'ID': 7, 'Name': 'Person_7', 'Age': 37, 'City': 'City_B', 'Occupation': 'Job_7'}, {'ID': 8, 'Name': 'Person_8', 'Age': 38, 'City': 'City_B', 'Occupation': 'Job_8'}]

# %%
pipeline = dlt.pipeline(destination='duckdb', dataset_name='merge_user_data')

# %%
info = pipeline.run(data1,
					table_name="merge_test",
					write_disposition="merge",
                    merge_key="ID"
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-6c5d9d26b2b2> in <cell line: 1>()
# ----> 1 info = pipeline.run(data1,
#       2                                         table_name="merge_test",
#       3                                         write_disposition="merge",
#       4                     merge_key="ID"
#       5 )
#
# /usr/local/lib/python3.10/dist-packages/dlt/pipeline/pipeline.py in _wrap(self, *args, **kwargs)
#     191                     trace_step = start_trace_step(trace, cast(TPipelineStep, f.__name__), self)
#     192
# --> 193                 step_info = f(self, *args, **kwargs)
#     194                 return step_info
#     195             except Exception as ex:
#
# /usr/local/lib/python3.10/dist-packages/dlt/pipeline/pipeline.py in _wrap(self, *args, **kwargs)
# ...
